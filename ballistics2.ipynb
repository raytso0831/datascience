# %%
from numpy import radians, sin
from numpy import linspace
import matplotlib.pyplot as plt
import pandas as pd

# %%
ballistics_points = [(x,(100**2)*sin(2*radians(x))/9.81) for x in linspace(0,90,200)]

# %%
plt.plot(ballistics_points)
plt.show()

# %%
df = pd.DataFrame(ballistics_points)

# %%
df.columns =  ['angle', 'range']

# %%
df
# Out:
#          angle         range
# 0     0.000000  0.000000e+00
# 1     0.452261  1.609199e+01
# 2     0.904523  3.217997e+01
# 3     1.356784  4.825993e+01
# 4     1.809045  6.432786e+01
# 5     2.261307  8.037976e+01
# 6     2.713568  9.641163e+01
# 7     3.165829  1.124195e+02
# 8     3.618090  1.283993e+02
# 9     4.070352  1.443471e+02
# 10    4.522613  1.602590e+02
# 11    4.974874  1.761309e+02
# 12    5.427136  1.919589e+02
# 13    5.879397  2.077391e+02
# 14    6.331658  2.234675e+02
# 15    6.783920  2.391402e+02
# 16    7.236181  2.547533e+02
# 17    7.688442  2.703029e+02
# 18    8.140704  2.857851e+02
# 19    8.592965  3.011962e+02
# 20    9.045226  3.165321e+02
# 21    9.497487  3.317892e+02
# 22    9.949749  3.469636e+02
# 23   10.402010  3.620515e+02
# 24   10.854271  3.770492e+02
# 25   11.306533  3.919529e+02
# 26   11.758794  4.067590e+02
# 27   12.211055  4.214636e+02
# 28   12.663317  4.360633e+02
# 29   13.115578  4.505542e+02
# ..         ...           ...
# 170  76.884422  4.505542e+02
# 171  77.336683  4.360633e+02
# 172  77.788945  4.214636e+02
# 173  78.241206  4.067590e+02
# 174  78.693467  3.919529e+02
# 175  79.145729  3.770492e+02
# 176  79.597990  3.620515e+02
# 177  80.050251  3.469636e+02
# 178  80.502513  3.317892e+02
# 179  80.954774  3.165321e+02
# 180  81.407035  3.011962e+02
# 181  81.859296  2.857851e+02
# 182  82.311558  2.703029e+02
# 183  82.763819  2.547533e+02
# 184  83.216080  2.391402e+02
# 185  83.668342  2.234675e+02
# 186  84.120603  2.077391e+02
# 187  84.572864  1.919589e+02
# 188  85.025126  1.761309e+02
# 189  85.477387  1.602590e+02
# 190  85.929648  1.443471e+02
# 191  86.381910  1.283993e+02
# 192  86.834171  1.124195e+02
# 193  87.286432  9.641163e+01
# 194  87.738693  8.037976e+01
# 195  88.190955  6.432786e+01
# 196  88.643216  4.825993e+01
# 197  89.095477  3.217997e+01
# 198  89.547739  1.609199e+01
# 199  90.000000  1.248366e-13
#
# [200 rows x 2 columns]

# %%
plt.plot(df)
plt.show()

# %%
plt.plot(df.range)
plt.show()

# %%
plt.plot(df.angle, df.range)
plt.xlabel(df.angle.name)
plt.ylabel(df.range.name)
plt.legend()
plt.show()

# %%
plt.scatter(df.angle, df.range)
plt.show()

# %%
df2 = pd.DataFrame()

# %%
#from numpy import linspace
df2['year'] = range (0, 300)
df2['value_float'] = 1000*(1.035)**df2.year
df2['value_str'] = ["$" + str(round (v)) for v in df2.value_float]

# %%
df2
# Out:
#      year   value_float    value_str
# 0       0  1.000000e+03      $1000.0
# 1       1  1.035000e+03      $1035.0
# 2       2  1.071225e+03      $1071.0
# 3       3  1.108718e+03      $1109.0
# 4       4  1.147523e+03      $1148.0
# 5       5  1.187686e+03      $1188.0
# 6       6  1.229255e+03      $1229.0
# 7       7  1.272279e+03      $1272.0
# 8       8  1.316809e+03      $1317.0
# 9       9  1.362897e+03      $1363.0
# 10     10  1.410599e+03      $1411.0
# 11     11  1.459970e+03      $1460.0
# 12     12  1.511069e+03      $1511.0
# 13     13  1.563956e+03      $1564.0
# 14     14  1.618695e+03      $1619.0
# 15     15  1.675349e+03      $1675.0
# 16     16  1.733986e+03      $1734.0
# 17     17  1.794676e+03      $1795.0
# 18     18  1.857489e+03      $1857.0
# 19     19  1.922501e+03      $1923.0
# 20     20  1.989789e+03      $1990.0
# 21     21  2.059431e+03      $2059.0
# 22     22  2.131512e+03      $2132.0
# 23     23  2.206114e+03      $2206.0
# 24     24  2.283328e+03      $2283.0
# 25     25  2.363245e+03      $2363.0
# 26     26  2.445959e+03      $2446.0
# 27     27  2.531567e+03      $2532.0
# 28     28  2.620172e+03      $2620.0
# 29     29  2.711878e+03      $2712.0
# ..    ...           ...          ...
# 270   270  1.081171e+07  $10811711.0
# 271   271  1.119012e+07  $11190121.0
# 272   272  1.158178e+07  $11581776.0
# 273   273  1.198714e+07  $11987138.0
# 274   274  1.240669e+07  $12406687.0
# 275   275  1.284092e+07  $12840922.0
# 276   276  1.329035e+07  $13290354.0
# 277   277  1.375552e+07  $13755516.0
# 278   278  1.423696e+07  $14236959.0
# 279   279  1.473525e+07  $14735253.0
# 280   280  1.525099e+07  $15250987.0
# 281   281  1.578477e+07  $15784771.0
# 282   282  1.633724e+07  $16337238.0
# 283   283  1.690904e+07  $16909042.0
# 284   284  1.750086e+07  $17500858.0
# 285   285  1.811339e+07  $18113388.0
# 286   286  1.874736e+07  $18747357.0
# 287   287  1.940351e+07  $19403514.0
# 288   288  2.008264e+07  $20082637.0
# 289   289  2.078553e+07  $20785529.0
# 290   290  2.151302e+07  $21513023.0
# 291   291  2.226598e+07  $22265979.0
# 292   292  2.304529e+07  $23045288.0
# 293   293  2.385187e+07  $23851873.0
# 294   294  2.468669e+07  $24686689.0
# 295   295  2.555072e+07  $25550723.0
# 296   296  2.644500e+07  $26444998.0
# 297   297  2.737057e+07  $27370573.0
# 298   298  2.832854e+07  $28328543.0
# 299   299  2.932004e+07  $29320042.0
#
# [300 rows x 3 columns]

# %%
plt.plot(df2.year, df2.value_float)
plt.show()
