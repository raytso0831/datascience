# %% [markdown]
# # Ballistics and the Range Equation #

# %% [markdown]
# This is an investigation of the so-called *range equation*: $d=\frac {v^2} g \sin 2\theta$.

# %%
from math import radians, sin, pi
from numpy import linspace
import matplotlib.pyplot as plt

# %%
def rangeformula(v, theta):
    d = (v**2)/9.81 * sin (2* theta)
    return d

# %% [markdown]
# angledegrees = range(0,91)

# %%
rangefromdegrees =[rangeformula(100, radians(angle)) for angle in angledegrees]

# %%
plt.plot(angledegrees, rangefromdegrees)
plt.title('Range as a function of angle at 100 m/s')
plt.xlabel('Angle (degrees)')
plt.ylabel('Range (meters)')
plt.show()

# %%
angleradians = (linspace(0, pi/2, num= 200))

# %%
rangefromradians =[rangeformula(100,angle) for angle in angleradians]

# %%
plt.plot(angleradians, rangefromradians)
plt.title('Range as a function of angle at 100 m/s')
plt.xlabel('Angle (radians)')
plt.ylabel('Range (meters)')
plt.show()

# %%
velocityrange = (linspace(0, 100, num= 200))

# %%
rangefromvelocity =[rangeformula(x,radians(45)) for x in velocityrange]

# %%
plt.plot(velocityrange, rangefromvelocity)
plt.title("Range as a function of initial velocity, for 45°")
plt.xlabel('angle')
plt.ylabel('Range (meters)')
plt.show()

# %%
rangefromvelocity15 =[rangeformula(x,radians(15)) for x in velocityrange]
rangefromvelocity30 =[rangeformula(x,radians(30)) for x in velocityrange]
rangefromvelocity45 =[rangeformula(x,radians(45)) for x in velocityrange]
rangefromvelocity60 =[rangeformula(x,radians(60)) for x in velocityrange]
rangefromvelocity75 =[rangeformula(x,radians(75)) for x in velocityrange]

# %%
plt.plot(velocityrange, rangefromvelocity15)
plt.plot(velocityrange, rangefromvelocity30)
plt.plot(velocityrange, rangefromvelocity45)
plt.plot(velocityrange, rangefromvelocity60)
plt.plot(velocityrange, rangefromvelocity75)
plt.title("Range as a function of initial velocity, for 15°,30°,45°,60°,75°")

# %% [markdown]
# # Advantages: It is easy to change the formula or initial conditions. You can see the graph update immediately.
# # Disadvantages: Availability and Accessibility
